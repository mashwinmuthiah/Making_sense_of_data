# %%
! pip install plotly
# Out:
# ...
#   Running setup.py bdist_wheel for retrying: started
#   Running setup.py bdist_wheel for retrying: finished with status 'done'
#   Stored in directory: C:\Users\ashwi\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# ...
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
! pip install cufflinks
# Out:
# ...
#   Running setup.py bdist_wheel for cufflinks: started
#   Running setup.py bdist_wheel for cufflinks: finished with status 'done'
#   Stored in directory: C:\Users\ashwi\AppData\Local\pip\Cache\wheels\ef\6a\a4\ff5ceff51314afb5bb24745bf74b51ed4cee53609b66bafa1c
# Successfully built cufflinks
# ...
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
api_keys = "50abcEPYjVyi66fL6eau"

# %%
user_name = "ashwin_muth"

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

# %%
tls.set_credentials_file(username=user_name,api_key=api_keys)

# %%
a = np.linspace(start=0,stop=36,num = 36)
np.random.seed(45)
b = np.random.uniform(low=0,high=50,size = 36)
trace = go.Scatter(x=a,y=b)
data = [trace]
py.iplot(data,file = "Simple Line Chart")
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~ashwin_muth/0 or inside your plot.ly account where it is named 'plot from API'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ashwin_muth/0.embed" height="525px" width="100%"></iframe>

# %%
data = pd.read_csv(r"C:\Users\ashwi\Downloads\IceCreamDataSet.csv")
data
# Out:
# C:\Users\ashwi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning:
#
# Columns (0,1,2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#                  Customer                      Date          Flavor     ...     Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0           Drew Roulette   Thursday, March 1, 2018       Chocolate     ...            NaN        NaN         NaN
# 1              Don Frazon     Friday, March 2, 2018         Vanilla     ...            NaN        NaN         NaN
# 2           Erin Davidson     Friday, March 2, 2018         Vanilla     ...            NaN        NaN         NaN
# 3               Ted Price     Friday, March 2, 2018       Chocolate     ...            NaN        NaN         NaN
# 4            Lila Stevens   Saturday, March 3, 2018    Cookie Dough     ...            NaN        NaN         NaN
# ...

# %%
data = data.drop(labels=["Unnamed: 5","Unnamed: 6","Unnamed: 7"], axis=1)

# %%
data = data.drop(data.index[86:])

# %%
data
# Out:
#             Customer                       Date          Flavor Revenue Profit
# 0      Drew Roulette    Thursday, March 1, 2018       Chocolate   $4.00  $3.00
# 1         Don Frazon      Friday, March 2, 2018         Vanilla   $4.00  $3.00
# 2      Erin Davidson      Friday, March 2, 2018         Vanilla   $4.00  $3.00
# 3          Ted Price      Friday, March 2, 2018       Chocolate   $4.00  $3.00
# 4       Lila Stevens    Saturday, March 3, 2018    Cookie Dough   $5.00  $3.75
# 5      Sierra Noonan    Saturday, March 3, 2018    Cookie Dough   $5.00  $3.75
# 6     Ian Richardson    Saturday, March 3, 2018       Chocolate   $4.00  $3.00
# 7      Drew Roulette      Sunday, March 4, 2018  Chocolate Chip   $5.00  $3.75
# 8      Sean Lansfrow      Sunday, March 4, 2018         Vanilla   $4.00  $3.00
# 9   Malcolm Benjamin      Sunday, March 4, 2018    Cookie Dough   $5.00  $3.75
# 10     Erin Davidson     Tuesday, March 6, 2018    Cookie Dough   $5.00  $3.75
# ...

# %%
a=data['Date']
b=data['Profit']

# %%
trace = go.Bar(x=a,y=b)
data = [trace]
py.iplot(data,file = "Simple Line Chart")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ashwin_muth/4.embed" height="525px" width="100%"></iframe>
